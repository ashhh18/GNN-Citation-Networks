# %%
# *********** Graph properties start here ************************

import networkx as nx 
# G=nx.DiG1aphs[k]aphs[k]aphs[k]aphs[k]aphs[k]aphs[k]aphs[k]aphs[k]aph()
import matplotlib.pyplot as plt
with open ('Datasets/1992to1993.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G1=nx.DiGraph()
G1.add_edges_from(edge1)
with open ('Datasets/1992to1994.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G2=nx.DiGraph()
G2.add_edges_from(edge1)

with open ('Datasets/1992to1995.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G3=nx.DiGraph()
G3.add_edges_from(edge1)
# print(G1)
with open ('Datasets/1992to1996.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G4=nx.DiGraph()
G4.add_edges_from(edge1)
with open ('Datasets/1992to1997.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G5=nx.DiGraph()
G5.add_edges_from(edge1)

with open ('Datasets/1992to1998.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G6=nx.DiGraph()
G6.add_edges_from(edge1)
# print(G1)

with open ('Datasets/1992to1999.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G7=nx.DiGraph()
G7.add_edges_from(edge1)
with open ('Datasets/1992to2000.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G8=nx.DiGraph()
G8.add_edges_from(edge1)
with open ('Datasets/1992to2001.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G9=nx.DiGraph()
G9.add_edges_from(edge1)

with open ('Datasets/cit-HepPh.txt','r') as f:
    l1=f.readlines()

edge1=[]
count=0
for line in l1:
    if(count<4):
        count+=1
        continue
    else:
        edge1.append((int(line.strip().split()[0]),int(line.strip().split()[1])))

G10=nx.DiGraph()
G10.add_edges_from(edge1)
print(G1)
print(G2)
print(G3)
print(G4)
print(G5)
print(G6)
print(G7)
print(G8)
print(G9)
print(G10)
graphs=[G1,G2,G3,G4,G5,G6,G7,G8,G9,G10]
# print(graphs)
# Out:
# DiGraph with 1528 nodes and 2919 edges
# DiGraph with 3892 nodes and 11519 edges
# DiGraph with 6884 nodes and 30055 edges
# DiGraph with 10177 nodes and 59236 edges
# DiGraph with 13787 nodes and 98687 edges
# DiGraph with 17621 nodes and 143301 edges
# DiGraph with 21627 nodes and 201485 edges
# DiGraph with 26192 nodes and 265655 edges
# DiGraph with 29877 nodes and 334212 edges
# DiGraph with 34546 nodes and 421578 edges

# %%
# Directed louvain Algorithm for community detection

# partitions=[]
# # node to community index map in partitions
# mapping={}
# count=0
# paritions_sums=[]
# for i in G7.nodes:
#     partitions.append([i])
#     mapping[i]=count
#     count+=1

# for i in G7.nodes:
#     temp={}
#     sums_in=0
#     sums_out_tot=0
#     sums_in_tot=0
#     for j in G7.out_edges(i):
#         if(mapping[i]==mapping[j[1]]):
#             sums_in+=1
#         sums_out_tot+=1
#     for j in G7.in_edges(i):
#         if(mapping[j[0]]==mapping[i]):
#             sums_in+=1
#         sums_in_tot+=1
#     temp['sums_in']=sums_in
#     temp['sums_in_tot']=sums_in_tot
#     temp['sums_out_tot']=sums_out_tot
#     paritions_sums.append(temp)

    
# def delta_modularity_calc_add(comm,new_node):
#     deno=len(G7.edges())
#     # sum_in=paritions_sums[mapping[i]]['sums_in']
#     sums_in_tot=paritions_sums[mapping[i]]['sums_in_tot']
#     sums_out_tot=paritions_sums[mapping[i]]['sums_out_tot']
#     new_ins=0
#     new_out_tot=0
#     new_in_tot=0
#     for j in G7.out_edges(new_node):
#         if(mapping[j[1]]==mapping[comm[0]]):
#             new_ins+=1
#         new_out_tot+=1
#     for j in G7.in_edges(new_node):
#         if(mapping[j[0]]==mapping[comm[0]]):
#             new_ins+=1
#         new_in_tot+=1
#     val=((new_ins)/deno)-((G7.in_degree(new_node)*(new_out_tot+sums_out_tot)+(new_in_tot+sums_in_tot)*G7.out_degree(new_node))/deno**2)
#     return val,new_ins,new_in_tot,new_out_tot

# def delta_modularity_calc_rem(comm,old_node):
#     deno=len(G7.edges())
#     # sum_in=paritions_sums[mapping[i]]['sums_in']
#     sums_in_tot=paritions_sums[mapping[i]]['sums_in_tot']
#     sums_out_tot=paritions_sums[mapping[i]]['sums_out_tot']
#     old_ins=0
#     old_out_tot=0
#     old_in_tot=0
#     for j in G7.out_edges(old_node):
#         if(mapping[j[1]]==mapping[comm[0]]):
#             old_ins+=1
#         old_out_tot+=1
#     for j in G7.in_edges(old_node):
#         if(mapping[j[0]]==mapping[comm[0]]):
#             old_ins+=1
#         old_in_tot+=1
#     val=-((old_ins)/deno)+((G7.in_degree(old_node)*(old_out_tot+sums_out_tot)+(old_in_tot+sums_in_tot)*G7.out_degree(old_node))/deno**2)
#     return val,old_ins,old_in_tot,old_out_tot
            
# # Phase 1
# count=0
# flag=1
# while(flag==1 and count<10):
#     print(count)
#     flag=0
#     for i in G7.nodes:
#         for j in G7.edges(i):
#             deltaQadd,new_ins,new_in_tot,new_out_tot=delta_modularity_calc_add(partitions[mapping[j[1]]],j[0])
#             deltaQrem,old_ins,old_in_tot,old_out_tot=delta_modularity_calc_rem(partitions[mapping[j[0]]],j[0])
#             if(deltaQadd+deltaQrem>0):
#                 partitions[mapping[j[1]]].append(j[0])
#                 partitions[mapping[j[0]]].remove(j[0])
#                 paritions_sums[mapping[j[0]]]['sums_in_tot']-=old_in_tot
#                 paritions_sums[mapping[j[0]]]['sums_out_tot']-=old_out_tot
#                 paritions_sums[mapping[j[1]]]['sums_in_tot']+=new_in_tot
#                 paritions_sums[mapping[j[1]]]['sums_out_tot']+=new_out_tot
#                 flag=1
#                 mapping[j[0]]=mapping[j[1]]
#     count+=1
# sum=0
# print(flag)
# new_partitions=[]
# for i in partitions:
#     if(len(i)!=0):
#         new_partitions.append(i)
# print(new_partitions)
# print(len(new_partitions))           

number_of_communities=[499,1007,1454,1707,1929,2175,2304] # calculated using the above commented code
years=[1993,1994,1995,1996,1997,1998,1999]
plt.plot(years,number_of_communities)
plt.xlabel('Year')
plt.ylabel('Number of communities')
plt.show()

# %%
built_in_communities=[]
for i in range(0,7):
    print(i)
    built_in_communities.append(nx.community.louvain_communities(graphs[i]))
print(built_in_communities)

sizes=[]
for i in built_in_communities:
    sizes.append(len(i))
years=[1993,1994,1995,1996,1997,1998,1999]
plt.plot(years,sizes)
plt.xlabel('Year')
plt.ylabel('Number of communities')
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# ...
